# %%
import pandas as pd
import nltk

# %%
data = pd.read_csv(r'news_sentiment_analysis.csv')
data.head(3)
# Out:
#           Source          Author  \
# 0        stgnews  Bridger Palmer
# 1  Zimbabwe Mail  Staff Reporter
# 2      4-traders             NaN
#
#                                                Title  \
# 0  Pine View High teacher wins Best in State awar...
# 1  Businesses Face Financial Strain Amid Liquidit...
# 2  Musk donates to super pac working to elect Tru...
#
#                                          Description  \
# 0  ST. GEORGE — Kaitlyn Larson, a first-year teac...
# 1  Harare, Zimbabwe – Local businesses are grappl...
# 2  (marketscreener.com) Billionaire Elon Musk has...
#
#                                                  URL  \
# 0  https://www.stgeorgeutah.com/news/archive/2024...
# 1  https://www.thezimbabwemail.com/business/busin...
# 2  https://www.marketscreener.com/business-leader...
#
#                 Published At Sentiment      Type
# 0  2024-07-12T23:45:25+00:00  positive  Business
# 1  2024-07-12T22:59:42+00:00   neutral  Business
# ...

# %%
data.columns
# Out:
# Index(['Source', 'Author', 'Title', 'Description', 'URL', 'Published At',
#        'Sentiment', 'Type'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Source        3500 non-null   object
#  1   Author        2512 non-null   object
#  2   Title         3500 non-null   object
#  3   Description   3500 non-null   object
#  4   URL           3500 non-null   object
#  5   Published At  3500 non-null   object
#  6   Sentiment     3500 non-null   object
#  7   Type          3500 non-null   object
# dtypes: object(8)
# memory usage: 218.9+ KB

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
# we need to tokenize the document by doing the sentence tokenizer and then work tokenizer on each sentnce .
# downloa the necessery package for the nltk

# %%
stop_words = set(stopwords.words('english'))
print(stop_words,end="")
# Out:
# {'wasn', "she'll", "needn't", "they've", 's', 'was', 'with', 'doing', "we're", "wouldn't", 'of', 'no', 'any', 'it', 'only', "won't", 'should', 'hasn', 'she', 'my', 'once', 'then', 'his', 'than', 'me', 'mightn', "we've", 'did', 'very', "she'd", 'yourself', 'in', 'him', 'ours', "shouldn't", 'here', "hadn't", "don't", 'does', 'each', 'them', 'doesn', "he'd", "doesn't", 'not', 'while', "she's", "he'll", 'those', 'up', "i'm", 'whom', 'some', 'but', 'be', 'ain', 'about', 'both', 'what', 'an', 'more', 'herself', 'on', 'hadn', 'hers', 'm', 'her', 'its', 'who', "you'd", "that'll", 'again', "we'd", 'until', 'when', 'and', 'or', 'we', "you'll", 'i', "wasn't", 'll', 'will', 'before', 'off', 'you', 'have', 'few', 'where', 'from', "shan't", 'below', 'mustn', 'having', 'there', "you're", "i'd", "aren't", 'needn', 'through', 'y', 'at', 'are', 'into', "should've", 'd', "weren't", 'for', 'own', 'itself', "mightn't", "they'd", 'myself', 'so', 'himself', "couldn't", 'down', 'he', 'other', "i'll", 'shan'
# ...

# %%
# # sentence tokenization
# sentence_tokens = sent_tokenize(corpus,language='english')
# filtered_sentence = [i for i in str(corpus).split(".") if i not in stop_words]
# unique_sentence = set(sentence_tokens)
# sentence_withought_stop_word = unique_sentence.difference(stop_words)
# print(sentence_withought_stop_word)
# print("*"*50)

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lematizer = WordNetLemmatizer()
lematizer.lemmatize('',pos='v')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ''

# %%
# preprocesing P1 Textpreprocessing , Lower cace , and implementing regex on whole text . 
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import re 
from nltk.stem import WordNetLemmatizer

lematizer = WordNetLemmatizer()

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'wasn', "she'll", "needn't", "they've", 's', 'was', 'with', 'doing', "we're", "wouldn't", 'of', 'no', 'any', 'it', 'only', "won't", 'should', 'hasn', 'she', 'my', 'once', 'then', 'his', 'than', 'me', 'mightn', "we've", 'did', 'very', "she'd", 'yourself', 'in', 'him', 'ours', "shouldn't", 'here', "hadn't", "don't", 'does', 'each', 'them', 'doesn', "he'd", "doesn't", 'not', 'while', "she's", "he'll", 'those', 'up', "i'm", 'whom', 'some', 'but', 'be', 'ain', 'about', 'both', 'what', 'an', 'more', 'herself', 'on', 'hadn', 'hers', 'm', 'her', 'its', 'who', "you'd", "that'll", 'again', "we'd", 'until', 'when', 'and', 'or', 'we', "you'll", 'i', "wasn't", 'll', 'will', 'before', 'off', 'you', 'have', 'few', 'where', 'from', "shan't", 'below', 'mustn', 'having', 'there', "you're", "i'd", "aren't", 'needn', 'through', 'y', 'at', 'are', 'into', "should've", 'd', "weren't", 'for', 'own', 'itself', "mightn't", "they'd", 'myself', 'so', 'himself', "couldn't", 'down', 'he', 'other', "i'll", 'shan'
# ...

# %%
def Lematizer_function (Text):
    lematizer = WordNetLemmatizer()
    return lematizer.lemmatize(Text)

# %%
def text_preprocessing (text):
    """ this funtion help to preprocess the data 
        1.Lowercasing
        2.Removing non-alphabets
        3.Stopword removal
        4.Tokenition
        5.Lemmatization
        6.storing the clean text in to list and return the list 
    
    """
    stop_words = set(stopwords.words('english'))
    corpus  = []
    for i in text:
        try:
            # Text lowering
            text = i.lower()

            # removing non-alphabatic characxters 
            text = re.sub(r'[^a-zA-Z]',' ',text)
            # Tokenization of words 
            words_tokens = word_tokenize(text,language="english")
            # remove stop_words and apply Lematization
            clean_word =  [Lematizer_function (word) for word in words_tokens if  not word  in stop_words]

            # join the clean word to make sentence 
            clean_text = ' '.join(clean_word)

            # append the clean word to corpus list 

            corpus.append(clean_text)



        except Exception as e:
            print("Erroe:"e)
            return corpus.append("")
    return corpus

# %%
corpus  = []
for i in data['Description']:
    try :
        text = i.lower()
        text = re.sub(r'[^a-zA-Z]',' ',text)
        
        words_tokens = word_tokenize(text,language="english")
        clean_word =  [Lematizer_function (word) for word in words_tokens if  not word  in stop_words]
        clean_text = ' '.join(clean_word)
        corpus.append(clean_text)
        print(clean_text)
    except Exception as e:
        print(e)
# Out:
# st george kaitlyn larson first year teacher pine view high school recently received best state award business leadership course larson student grade highest passing rate youscience exam spring fall semester youscience exam similar final exam
# harare zimbabwe local business grappling severe liquidity crunch limiting
# marketscreener com billionaire elon musk donated super pac working elect former u president donald trump bloomberg reported friday citing source report indicate much musk donated added sizable amount given group called america pac http www marketscreener com business leader elon musk news musk donates super pac working elect trump bloomberg report utm medium rss utm content
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer( binary=True)

# %%
x= cv.fit_transform(corpus)

# %%
cv.vocabulary_
# Out:
# {'st': 14571,
#  'george': 6473,
#  'kaitlyn': 8313,
#  'larson': 8673,
#  'first': 5951,
#  'year': 17000,
#  'teacher': 15184,
#  'pine': 11501,
#  'view': 16435,
#  'high': 7097,
#  'school': 13563,
#  'recently': 12577,
#  'received': 12571,
#  'best': 1732,
#  'state': 14628,
#  'award': 1386,
#  'business': 2212,
#  'leadership': 8736,
#  'course': 3569,
#  'student': 14797,
#  'grade': 6690,
#  'highest': 7100,
#  'passing': 11213,
#  'rate': 12477,
#  'youscience': 17031,
#  'exam': 5464,
#  'spring': 14535,
#  'fall': 5673,
#  'semester': 13758,
#  'similar': 14062,
#  'final': 5895,
#  'harare': 6906,
#  'zimbabwe': 17097,
#  'local': 9008,
#  'grappling': 6715,
#  'severe': 13874,
#  'liquidity': 8944,
#  'crunch': 3675,
#  'limiting': 8917,
#  'marketscreener': 9340,
#  'com': 3037,
#  'billionaire': 1816,
#  'elon': 4956,
#  'musk': 10083,
#  'donated': 4550,
#  'super': 14921,
#  'pac': 11043,
#  'working': 16906,
#  'elect': 4901,
#  'former': 6102,
# ...

# %%
# for i in tf_idf_vactor.get_feature_names_out():
#     print(i,end =', ')

# %%
#  beta model creation using ML

# %%
# available data 
# corpus
# tfidf_data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report , confusion_matrix
from sklearn.preprocessing import LabelEncoder 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

# %%
lable = LabelEncoder()
data['labled_sentiment'] = lable.fit_transform(data['Sentiment'])
data['labled_sentiment']
# Out:
# 0       2
# 1       1
# 2       2
# 3       0
# 4       2
#        ..
# 3495    2
# 3496    2
# 3497    2
# 3498    1
# 3499    2
# Name: labled_sentiment, Length: 3500, dtype: int32

# %%
# data['Sentiment'].value_counts()
data['labled_sentiment'].value_counts()
# Out:
# labled_sentiment
# 2    2134
# 1     789
# 0     577
# Name: count, dtype: int64

# %%
x = corpus
y = data['labled_sentiment']

# %%
x_train, x_test , y_train , y_test = train_test_split(x , y ,test_size=0.2,random_state=42,stratify=y)

# %%
tf_idf_vactor = TfidfVectorizer(max_features = 1000 ,ngram_range=(1,3))
x_train_vec = tf_idf_vactor.fit_transform(x_train)
x_test_vec = tf_idf_vactor.fit_transform(x_test)

# %%
# model trainig 
model = LogisticRegression(max_iter = 100, class_weight = 'balanced')
model.fit(x_train_vec, y_train)

# Evaluate
y_pred = model.predict(x_test_vec)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.19      0.17      0.18       115
#            1       0.47      0.48      0.47       158
#            2       0.69      0.70      0.70       427
#
#     accuracy                           0.56       700
#    macro avg       0.45      0.45      0.45       700
# weighted avg       0.56      0.56      0.56       700

# %%
# model 2 
from sklearn.naive_bayes import MultinomialNB
model_2 = MultinomialNB()
model_2.fit(x_train_vec,y_train)

# evalution
y_pred_2 = model_2.predict(x_test_vec)
print(classification_report(y_test,y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.07      0.11       115
#            1       0.49      0.32      0.38       158
#            2       0.65      0.85      0.74       427
#
#     accuracy                           0.60       700
#    macro avg       0.46      0.41      0.41       700
# weighted avg       0.54      0.60      0.55       700

# %%
svm_model = SVC(kernel = 'sigmoid',max_iter = 100, class_weight = 'balanced')
svm_model.fit(x_train_vec,y_train)

svm_pred = svm_model.predict(x_test_vec)

print(" Classification Report:")
print(classification_report(y_test, y_pred))

print("\n Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
#  Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.19      0.17      0.18       115
#            1       0.47      0.48      0.47       158
#            2       0.69      0.70      0.70       427
#
#     accuracy                           0.56       700
#    macro avg       0.45      0.45      0.45       700
# weighted avg       0.56      0.56      0.56       700
#
#
#  Confusion Matrix:
# [[ 20  20  75]
#  [ 25  76  57]
#  [ 62  66 299]]
# c:\Users\HP\anaconda3\envs\parva_ds\Lib\site-packages\sklearn\svm\_base.py:305: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
raw_data = pd.read_csv(r"E:\AI Engineearing\Projects\job_finder_proj\Sentimantal_analysis\news_data.csv")
raw_data.columns
# Out:
# Index(['Headline', 'Context', 'Link'], dtype='object')

# %%
# raw text preprocessing 
raw_data_corpus  = []
for i in raw_data['Context']:
    try :
        text = i.lower()
        text = re.sub(r'[^a-zA-Z]',' ',text)
        stop_words = set(stopwords.words('english'))
        words_tokens = word_tokenize(text,language="english")
        clean_word =  [Lematizer_function (word) for word in words_tokens if  not word  in stop_words]
        clean_text = ' '.join(clean_word)
        raw_data_corpus.append(clean_text)
        print(raw_data_corpus)
    except Exception as e:
        print(e)
# Out:
# ['toi entertainment desk dynamic dedicated team journalist working tirelessly bring pulse entertainment world straight reader time india red carpet go unrolled stage go dark team span globe bringing latest scoop insider insight bollywood hollywood every entertainment hotspot report tell tale stardom story untold whether rise new sensation seasoned journey industry veteran toi entertainment desk front row seat fascinating narrative shape entertainment landscape beyond breaking news present celebration culture explore intersection entertainment society politics everyday life read rise fall pawan singh top hilarious moment show think good parent everyday habit say otherwise stunning pic divyanka tripathi ethnic ace festive season pic attractive look actress sneha']
# ...

# %%
#  application on rqaw data
tfidf = TfidfVectorizer(max_features=1000,ngram_range=(2,3))

x_raw = tfidf.fit_transform(raw_data_corpus)
raw_df = model_2.predict(x_raw)

df = pd.DataFrame({"Hedlines":raw_data['Headline'],"sentence":raw_data_corpus,"sentiment":raw_df})
df['sentiment']= df['sentiment'].replace({0:'Negative',1:'Neutral',2:'Positive'})
df
# Out:
#                                              Hedlines  \
# 0   Times of India\nRishabh Shetty’s 'Kantara:Chap...
# 1   USA Today\nHuman remains believed to be Travis...
# 2   USA Today\nBills win 13th straight game at hom...
# 3   Sportstar\nUSA beats Kazakhstan to set up Bill...
# 4   Fox News\nTurning Point USA elects Erika Kirk ...
# 5   The News Minute\nKerala man who complained of ...
# 6   Maktoob Media\nKerala bank employee who faced ...
# 7   Times of India\nNabha jailbreak: How a Khalist...
# 8   The New Indian Express\nNabha jailbreak accuse...
# 9   Live Law\nInsured Should Take All Reasonable S...
# 10  The Guardian\nChina’s ‘temple economy’ in the ...
# 11  Financial Times\nChina drops Google antitrust ...
# 12  India Today\nUS blocks Pak-China bid to sancti...
# 13  The Hindu\nChina Masters Super 750 Badminton: ...
# 14  Times of India\n'India & China are ancient civ...
#
#                                              sentence sentiment
# ...

# %%
import sqlite3

# %%
type(raw_data_corpus)
# Out:
# list
